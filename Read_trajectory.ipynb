# %%
import csv
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
file = "LS2D2020_11_10_00_00_00_000000-600000000.0-200.csv"

# %%
t = pd.read_csv(file, sep=',',header=None)

# %%
t
# Out:
#        0   1   2   3   4    5            6            7            8   \
# 0    2020  11  10   0   0  0.0 -1157.672060 -4689.613861 -5000.327876
# 1    2020  11  10   0  10  0.0 -2418.943987 -6415.890287 -1086.106701
# 2    2020  11  10   0  20  0.0 -2678.024713 -5484.799019  3277.061437
# 3    2020  11  10   0  30  0.0 -1822.881386 -2271.989429  6272.320258
# 4    2020  11  10   0  40  0.0  -208.289166  1887.292900  6647.256965
# ..    ...  ..  ..  ..  ..  ...          ...          ...          ...
# 195  2020  11  11   8  30  0.0 -1327.250628  -961.654804  6716.165167
# 196  2020  11  11   8  40  0.0   303.313429  3168.341935  6139.211104
# 197  2020  11  11   8  50  0.0  1807.458679  5977.752855  2996.592443
# 198  2020  11  11   9   0  0.0  2559.312588  6298.687690 -1397.732073
# 199  2020  11  11   9  10  0.0  2250.894795  4009.411091 -5213.559030
#
#              9          10            11           12
# 0    241.897665 -65.206661  1.219209e+07  6952.406895
# ...

# %%
t_np = t.to_numpy()

# %%
t_np.shape
# Out:
# (200, 13)

# %%
phi = t_np[:,9]
theta = t_np[:,10]
r = t_np[:,-1]/1000
print(r)
# Out:
# [6.9524069  6.94223062 6.92776792 6.91569475 6.91312404 6.921491
#  6.93539364 6.94775355 6.95467687 6.95520201 6.9489032  6.93637209
#  6.92193499 6.91319386 6.91549225 6.92709687 6.94109953 6.95142603
#  6.95570075 6.9533992  6.94425034 6.93013377 6.91713588 6.91273376
#  6.91957119 6.93311641 6.94611026 6.95400665 6.95555909 6.95035873
#  6.9386655  6.92407384 6.91391634 6.91435145 6.92487047 6.93900489
#  6.95017978 6.95545603 6.95421524 6.94612823 6.93251987 6.9188109
#  6.91265324 6.9178273  6.93081033 6.94432542 6.95317867 6.95575001
#  6.95164022 6.94086955 6.92632666 6.91493055 6.91348575 6.92273111
#  6.93681835 6.94877818 6.9550526  6.95485767 6.94785147 6.93489222
#  6.92068947 6.91288546 6.91629153 6.92850503 6.94240808 6.9521923
#  6.95577777 6.95274609 6.94296151 6.92865664 6.91621782 6.91291323
#  6.92071397 6.93456126 6.94722389 6.95449073 6.95532972 6.94941088
#  6.9372194  6.92273817 6.91342708 6.91499326 6.9262327  6.94037051
# ...

# %%
x = t_np[:,6]/1000
y = t_np[:,7]/1000
z = t_np[:,8]/1000
p_traj_list = t_np[:,6:9]/1000
p_traj_list
# Out:
# array([[-1.15767206, -4.68961386, -5.00032788],
#        [-2.41894399, -6.41589029, -1.0861067 ],
#        [-2.67802471, -5.48479902,  3.27706144],
#        [-1.82288139, -2.27198943,  6.27232026],
#        [-0.20828917,  1.8872929 ,  6.64725696],
#        [ 1.49306788,  5.25976875,  4.24412756],
#        [ 2.57230145,  6.44037556,  0.06717856],
#        [ 2.58334782,  4.9458696 , -4.13956124],
#        [ 1.5286274 ,  1.41004297, -6.63646046],
#        [-0.15310679, -2.70484446, -6.40587307],
#        [-1.77159108, -5.70970762, -3.54230993],
#        [-2.65864303, -6.35844937,  0.78421716],
#        [-2.44180473, -4.36767006,  4.78270132],
#        [-1.20817113, -0.55831233,  6.78386757],
#        [ 0.52888992,  3.48358641,  5.95054066],
#        [ 2.04545324,  6.07321414,  2.6299928 ],
#        [ 2.71055109,  6.13430063, -1.78945001],
#        [ 2.25288105,  3.65364844, -5.46787928],
#        [ 0.8683883 , -0.33098342, -6.89333915],
#        [-0.87184699, -4.18017588, -5.48778396],
# ...

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(x[:20], y[:20], z[:20], label='parametric curve')
ax.legend()

ax1 = fig.gca(projection='3d')
# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x_ = 3 * np.outer(np.cos(u), np.sin(v))
y_ = 3 * np.outer(np.sin(u), np.sin(v))
z_ = 3 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax1.plot_surface(x_, y_, z_, color='g')

plt.show()
